# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ashik\Documents\Projects\EduGuard\data\student_performance_prediction.csv")
df.head()
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Parent Education Level Passed
# 0                                         Yes                 Master    Yes
# 1                                          No            High School     No
# 2                                          No              Associate     No
# 3                                         Yes               Bachelor     No
# 4                                          No                 Master     No

# %%
df.shape
# Out:
# (40000, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Student ID                                   40000 non-null  object
#  1   Study Hours per Week                         38005 non-null  float64
#  2   Attendance Rate                              38008 non-null  float64
#  3   Previous Grades                              38006 non-null  float64
#  4   Participation in Extracurricular Activities  38000 non-null  object
#  5   Parent Education Level                       38000 non-null  object
#  6   Passed                                       38000 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 2.1+ MB

# %%
df.isnull().sum()
# Out:
# Student ID                                        0
# Study Hours per Week                           1995
# Attendance Rate                                1992
# Previous Grades                                1994
# Participation in Extracurricular Activities    2000
# Parent Education Level                         2000
# Passed                                         2000
# dtype: int64

# %%
df.drop(columns=["Student ID"], inplace=True)

# %%
num_cols = [
    "Study Hours per Week",
    "Attendance Rate",
    "Previous Grades"
]
for col in num_cols:
    df[col] = df[col].fillna(df[col].mean())

# %%
df['Study Hours per Week']
# Out:
# 0        12.5
# 1         9.3
# 2        13.2
# 3        17.6
# 4         8.8
#          ...
# 39995    15.6
# 39996    11.3
# 39997    13.1
# 39998    14.1
# 39999    11.8
# Name: Study Hours per Week, Length: 40000, dtype: float64

# %%
cat_cols = [
    "Participation in Extracurricular Activities",
    "Parent Education Level",
    "Passed"
]
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Study Hours per Week                           0
# Attendance Rate                                0
# Previous Grades                                0
# Participation in Extracurricular Activities    0
# Parent Education Level                         0
# Passed                                         0
# dtype: int64

# %%
df.isnull()
# Out:
#        Study Hours per Week  Attendance Rate  Previous Grades  \
# 0                     False            False            False
# 1                     False            False            False
# 2                     False            False            False
# 3                     False            False            False
# 4                     False            False            False
# ...                     ...              ...              ...
# 39995                 False            False            False
# 39996                 False            False            False
# 39997                 False            False            False
# 39998                 False            False            False
# 39999                 False            False            False
#
#        Participation in Extracurricular Activities  Parent Education Level  \
# 0                                            False                   False
# ...

# %%
df["Passed"] = df["Passed"].map({"Yes": 1, "No": 0})

# %%
df = pd.get_dummies(
    df,
    columns=[
        "Participation in Extracurricular Activities",
        "Parent Education Level"
    ],
    drop_first=True
)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 9 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Study Hours per Week                             40000 non-null  float64
#  1   Attendance Rate                                  40000 non-null  float64
#  2   Previous Grades                                  40000 non-null  float64
#  3   Passed                                           40000 non-null  int64
#  4   Participation in Extracurricular Activities_Yes  40000 non-null  bool
#  5   Parent Education Level_Bachelor                  40000 non-null  bool
#  6   Parent Education Level_Doctorate                 40000 non-null  bool
#  7   Parent Education Level_High School               40000 non-null  bool
#  8   Parent Education Level_Master                    40000 non-null  bool
# ...

# %%
df.to_csv("../data/cleaned_student_data.csv", index=False)
